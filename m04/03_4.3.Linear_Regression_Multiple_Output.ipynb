# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to make a prediction using multiple samples.</li></ul>

# %% [markdown]
# # Table of Contents
# In this lab, we will  review how to make a prediction for Linear Regression with Multiple Output.
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <li><a href="#ref1">Class Linear </a></li>
#
# <br>
# <p></p>
# Estimated Time Needed: <strong>15 min</strong>
# </div>
#
# <hr>

# %% [markdown]
# <a id="ref1"></a>
# <a name="ref1"><h2 align=center>Class Linear  </h2></a>

# %%
# %%time
# %pip install torch==2.8.0+cpu torchvision==0.23.0+cpu torchaudio==2.8.0+cpu \
    --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch==2.8.0+cpu
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision==0.23.0+cpu
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.23.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio==2.8.0+cpu
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.8.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: filelock in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch==2.8.0+cpu) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch==2.8.0+cpu) (4.15.0)
# Requirement already satisfied: setuptools in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch==2.8.0+cpu) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch==2.8.0+cpu) (1.14.0)
# Requirement already satisfied: networkx in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch==2.8.0+cpu) (3.5)
# Requirement already satisfied: jinja2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch==2.8.0+cpu) (3.1.6)
# Requirement already satisfied: fsspec in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch==2.8.0+cpu) (2025.9.0)
# Requirement already satisfied: numpy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torchvision==0.23.0+cpu) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torchvision==0.23.0+cpu) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.8.0+cpu) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jinja2->torch==2.8.0+cpu) (3.0.2)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl (183.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 MB 150.7 MB/s  0:00:010:00:0100:01
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.23.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 122.9 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.8.0%2Bcpu-cp312-cp312-manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 100.8 MB/s  0:00:00
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu128
#     Uninstalling torch-2.8.0+cu128:━━━━━━━━━━━━━ 0/3 [torch]
#       Successfully uninstalled torch-2.8.0+cu128 0/3 [torch]
#   Attempting uninstall: torchvision━━━━━━━━━━━━━ 0/3 [torch]
#     Found existing installation: torchvision 0.23.0+cu128 [torch]
#     Uninstalling torchvision-0.23.0+cu128:━━ 0/3 [torch]
#       Successfully uninstalled torchvision-0.23.0+cu128/3 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchaudio]3 [torchaudio]]
# Successfully installed torch-2.8.0+cpu torchaudio-2.8.0+cpu torchvision-0.23.0+cpu
# Note: you may need to restart the kernel to use updated packages.
# CPU times: user 243 ms, sys: 62 ms, total: 305 ms
# Wall time: 19.6 s

# %%
from torch import nn
import torch

# %% [markdown]
# Set the random seed:

# %%
torch.manual_seed(1)

# %% [markdown]
# Set the random seed:

# %%
class linear_regression(nn.Module):
    def __init__(self,input_size,output_size):
        super(linear_regression,self).__init__()
        self.linear=nn.Linear(input_size,output_size)
    def forward(self,x):
        yhat=self.linear(x)
        return yhat

# %% [markdown]
# create a linear regression  object, as our input and output will be two we set the parameters accordingly

# %%
model=linear_regression(1,10)
model(torch.tensor([1.0]))

# %% [markdown]
# we can use the diagram to represent the model or object

# %% [markdown]
# <img src="https://ibm.box.com/shared/static/icmwnxru7nytlhnq5x486rffea9ncpk7.png" width="600," align="center">

# %% [markdown]
# we can see the parameters

# %%
list(model.parameters())

# %% [markdown]
# we can create a tensor with two rows representing one sample of data

# %%
x=torch.tensor([[1.0]])

# %% [markdown]
# we can make a prediction

# %%
yhat=model(x)
yhat

# %% [markdown]
# each row in the following tensor represents a different sample

# %%
X=torch.tensor([[1.0],[1.0],[3.0]])

# %% [markdown]
# we can make a prediction using multiple samples

# %%
Yhat=model(X)
Yhat

# %% [markdown]
# the following figure represents the operation, where the red and blue  represents the different parameters, and the different shades of green represent  different samples.

# %% [markdown]
#  <img src="https://ibm.box.com/shared/static/768cul6pj8hc93uh9ujpajihnp8xdukx.png" width="600," align="center">

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork&context=cpdaas&apps=data_science_experience%2Cwatson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"></a>

# %% [markdown]
# # About the Authors:
#
#  [Joseph Santarcangelo]( https://www.linkedin.com/in/joseph-s-50398b136/) has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# Other contributors: [Michelle Carey](  https://www.linkedin.com/in/michelleccarey/)

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-23  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
# -->

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
